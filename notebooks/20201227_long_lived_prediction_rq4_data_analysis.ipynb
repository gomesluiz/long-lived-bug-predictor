# %% [markdown]
# # Research Question No. 4
# What is the comparative performance of learning algorithms in long-lived bug prediction in FLOSS project? This research question aims to compare the accuracy of the long-lived bug prediction made by different classification algorithms. Here the algorithm with the best prediction capabilities is best fit in terms of balanced accuracy.

# %% [markdown]
# # 1. Setup environment.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt 
import numpy as np
import os 
import pandas as pd
import seaborn as sns 
from scipy.stats import friedmanchisquare
from scipy.stats import wilcoxon

# Setup Matplotlib
plt.rc('figure', figsize=(15, 15))
plt.style.use('default')
SMALL_SIZE = 12
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# %matplotlib inline 

# Setup Seaborn
sns.set_context("paper")
sns.set_style("ticks")


pd.set_option('display.max_columns', None)

bug_reports_eclipse_path = "../data/20200731_eclipse_bug_report_data.csv"
bug_reports_gcc_path     = "../data/20200731_gcc_bug_report_data.csv"
print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# # 2. Load data.

# %% [markdown]
# # 3. First Experiment

# %% [markdown]
# ## Experimental parameters

# %% [markdown]
# | Parameter                  |         Value        |
# |----------------------------|:--------------------:|
# | Project                    |        Eclipse       |
# | Algorithms                 | KNN, NB, NN, SVM, RF |
# | Metrics                    | Accuracy |
# | Features                   | Summary and Description |
# | Number of Terms            |        100       |
# | Balancing                  |        Unbalance, Smote   |
# | Resampling                 |        Repeated CV 5 x 10       |
# | Threshold                  |        365       |
#
#
#
#
#
#
#
#
# Every bug which its report have indicated that the number of days to resolve is less than or equal to **threshold fixed** was considered a **non-long lived bug** and that which the number of days to resolve is greater than this threshold was considered as a **long-live bug**.

# %% [markdown]
# ## 3.1 Review the data

# %% [markdown]
# ### Best Balanced Accuracy Scores

# %%
eclipse_metrics_in_train = pd.read_csv("../output/data/20200916_r4_1b_predict_long_lived_bug_train_final.csv", sep=",")
eclipse_metrics_in_train['sensitivity']  =  eclipse_metrics_in_train['tp']/(eclipse_metrics_in_train['tp']+eclipse_metrics_in_train['fn'])  
eclipse_metrics_in_train['specificity']  =  eclipse_metrics_in_train['tn']/(eclipse_metrics_in_train['tn']+eclipse_metrics_in_train['fp'])
eclipse_metrics_in_train['balanced_acc'] =  (eclipse_metrics_in_train['sensitivity']+eclipse_metrics_in_train['specificity'])/2
eclipse_metrics_in_train.fillna(0, inplace=True)

# %%
eclipse_metrics_in_train.sort_values('balanced_acc', ascending=False).head()
# Out:
#         tn  fp  fn    tp     Resample                acc  sensitivity  \
# 7509  1700  45   7  1664  Fold5.Rep02  0,984777517564403     0.995811
# 7534  1698  47   6  1665  Fold5.Rep07  0,984484777517564     0.996409
# 7517  1695  51   4  1666  Fold3.Rep04  0,983899297423888     0.997605
# 7502  1693  53   4  1667  Fold3.Rep01  0,983318700614574     0.997606
# 7539  1693  53   4  1666  Fold5.Rep08  0,983313817330211     0.997605
#
#       specificity  balanced_acc  project classifier balancing      resampling  \
# 7509     0.974212      0.985011  eclipse        svm     smote  repeatedcv5x10
# 7534     0.973066      0.984738  eclipse        svm     smote  repeatedcv5x10
# 7517     0.970790      0.984198  eclipse        svm     smote  repeatedcv5x10
# 7502     0.969645      0.983626  eclipse        svm     smote  repeatedcv5x10
# 7539     0.969645      0.983625  eclipse        svm     smote  repeatedcv5x10
#
#         metric  max_term           feature hyper1   value1 hyper2 value2  \
# 7509  Accuracy       100  long_description  sigma  0,03125      C     32
# 7534  Accuracy       100  long_description  sigma  0,03125      C     32
# 7517  Accuracy       100  long_description  sigma  0,03125      C     32
# 7502  Accuracy       100  long_description  sigma  0,03125      C     32
# 7539  Accuracy       100  long_description  sigma  0,03125      C     32
#
#      hyper3  value3  seed
# 7509      0       0   144
# 7534      0       0   144
# 7517      0       0   144
# 7502      0       0   144
# 7539      0       0   144

# %%
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train.groupby(['classifier', 'feature', 'balancing', 'metric', 'max_term']).agg({'sensitivity': 'mean', 'specificity':'mean', 'balanced_acc': 'mean'})
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train_summarized.reset_index()
eclipse_params_in_train = pd.read_csv("../output/data/20200914_r4_1a_predict_long_lived_bug_results_final.csv", sep=",")
eclipse_metrics_in_train_summarized=pd.merge(eclipse_metrics_in_train_summarized, eclipse_params_in_train[['classifier', 'feature', 'balancing', 'train_size', 'train_size_class_0', 'train_size_class_1', 'hyper1', 'value1', 'hyper2', 'value2', 'hyper3', 'value3']], on=['classifier', 'feature', 'balancing'])

# %%
pd.options.display.float_format = "{:,.3f}".format
eclipse_metrics_in_train_summarized.loc[eclipse_metrics_in_train_summarized.feature == "long_description", "feature"] = "description"
eclipse_metrics_in_train_summarized.loc[eclipse_metrics_in_train_summarized.feature == "short_description", "feature"] = "summary"
s = eclipse_metrics_in_train_summarized[['classifier', 'feature', 'balancing', 'max_term', 'train_size', 'train_size_class_0', 'train_size_class_1', 'balanced_acc', 'hyper1', 'value1', 'hyper2', 'value2', 'hyper3', 'value3']].sort_values('balanced_acc', ascending=False)
display(s)
# Out:
#    classifier      feature   balancing  max_term  train_size  \
# 16        svm  description       smote       100       17081
# 12         rf  description       smote       100       17081
# 14         rf      summary       smote       100       14863
# 18        svm      summary       smote       100       14863
# 10         nn      summary       smote       100       14863
# 2         knn      summary       smote       100       14863
# 0         knn  description       smote       100       17081
# 8          nn  description       smote       100       17081
# 4          nb  description       smote       100       17081
# 6          nb      summary       smote       100       14863
# 15         rf      summary  unbalanced       100        8252
# 13         rf  description  unbalanced       100        9425
# 11         nn      summary  unbalanced       100        8252
# 1         knn  description  unbalanced       100        9425
# 17        svm  description  unbalanced       100        9425
# 3         knn      summary  unbalanced       100        8252
# 19        svm      summary  unbalanced       100        8252
# 9          nn  description  unbalanced       100        9425
# 5          nb  description  unbalanced       100        9425
# 7          nb      summary  unbalanced       100        8252
#
#     train_size_class_0  train_size_class_1  balanced_acc hyper1  value1  \
# 16                8729                8352         0.981  sigma   0.031
# 12                8729                8352         0.951   mtry  25.000
# 14                7651                7212         0.907   mtry  50.000
# 18                7651                7212         0.888  sigma   0.031
# 10                7651                7212         0.837   size  30.000
# 2                 7651                7212         0.802      k   5.000
# 0                 8729                8352         0.782      k   5.000
# 8                 8729                8352         0.744   size  20.000
# 4                 8729                8352         0.533     fL   0.000
# 6                 7651                7212         0.524     fL   0.000
# 15                7651                 601         0.503   mtry  25.000
# 13                8729                 696         0.501   mtry  25.000
# 11                7651                 601         0.501   size  30.000
# 1                 8729                 696         0.500      k  33.000
# 17                8729                 696         0.500  sigma  32.000
# 3                 7651                 601         0.500      k  33.000
# 19                7651                 601         0.500  sigma  32.000
# 9                 8729                 696         0.500   size  10.000
# 5                 8729                 696         0.477     fL   0.000
# 7                 7651                 601         0.469     fL   0.000
#
#        hyper2  value2  hyper3  value3
# 16          C  32.000     NaN       0
# 12        NaN   0.000     NaN       0
# 14        NaN   0.000     NaN       0
# 18          C  32.000     NaN       0
# 10      decay   0.500     NaN       0
# 2         NaN   0.000     NaN       0
# 0         NaN   0.000     NaN       0
# 8       decay   0.500     NaN       0
# 4   usekernel   0.000  adjust       0
# 6   usekernel   0.000  adjust       0
# 15        NaN   0.000     NaN       0
# 13        NaN   0.000     NaN       0
# 11      decay   0.500     NaN       0
# 1         NaN   0.000     NaN       0
# 17          C   0.031     NaN       0
# 3         NaN   0.000     NaN       0
# 19          C   0.031     NaN       0
# 9       decay   0.500     NaN       0
# 5   usekernel   1.000  adjust       4
# 7   usekernel   1.000  adjust       2

# %%
s.to_latex('/tmp/eclipse_metrics_in_train_summarized.tex', index=False)
s.to_csv('/tmp/eclipse_metrics_in_train_summarized.csv', index=False)

# %%
def make_statistical_test(metrics_dataset):
    classifiers = ['knn', 'nb', 'nn', 'rf', 'svm']
    statistics  = pd.DataFrame(columns=['classifier1', 'mean1', 'classifier2', 'mean2', 'condition', 'direction'])
    alpha   = 0.05
    p       = 1.0
    for classifier1 in classifiers:
        sample1 = metrics_dataset.loc[:, (slice('balanced_acc'), classifier1)].values 
        mean1   = np.mean(sample1)
        for classifier2 in classifiers:
            sample2   = metrics_dataset.loc[:, (slice('balanced_acc'), classifier2)].values
            mean2     = np.mean(sample2)
            condition = True
            if (classifier1 != classifier2):
                stat, p   = wilcoxon(sample1.flatten(), sample2.flatten())
                condition = p > alpha
        
            statistics = statistics.append(
                {'classifier1': classifier1, 
                 'mean1': mean1, 
                 'classifier2': classifier2,
                 'mean2': mean2,
                 'condition': condition,
                 'direction': '$-$' if condition else '$\\leftarrow$' if mean1 > mean2 else '$\\uparrow$'}
                , ignore_index=True
            )
    return statistics

# %%
eclipse_metrics_in_train_by_fold = pd.pivot_table (eclipse_metrics_in_train, index=['Resample'], columns='classifier', values=['sensitivity', 'specificity', 'balanced_acc'])
statistics = make_statistical_test(eclipse_metrics_in_train_by_fold)
statistics.head()
# Out:
#   classifier1  mean1 classifier2  mean2 condition     direction
# 0         knn  0.646         knn  0.646      True           $-$
# 1         knn  0.646          nb  0.501     False  $\leftarrow$
# 2         knn  0.646          nn  0.646      True           $-$
# 3         knn  0.646          rf  0.716     False    $\uparrow$
# 4         knn  0.646         svm  0.717     False    $\uparrow$

# %%
s = statistics[['classifier1', 'classifier2', 'direction']]
s = s.pivot(index='classifier1', columns='classifier2', values='direction')
s.to_latex('/tmp/tabela_teste_estatistico.tex', index=True)
s
# Out:
# classifier2           knn            nb            nn            rf  \
# classifier1
# knn                   $-$  $\leftarrow$           $-$    $\uparrow$
# nb             $\uparrow$           $-$    $\uparrow$    $\uparrow$
# nn                    $-$  $\leftarrow$           $-$    $\uparrow$
# rf           $\leftarrow$  $\leftarrow$  $\leftarrow$           $-$
# svm          $\leftarrow$  $\leftarrow$  $\leftarrow$  $\leftarrow$
#
# classifier2         svm
# classifier1
# knn          $\uparrow$
# nb           $\uparrow$
# nn           $\uparrow$
# rf           $\uparrow$
# svm                 $-$

# %% [markdown]
# # 4. Second Experiment (RQ4.2)

# %% [markdown]
# ## 4.1 Parameters

# %% [markdown]
# | Parameter                  |         Value        |
# |----------------------------|:--------------------:|
# | Project                    |        Eclipse       |
# | Algorithms                 |        SVM |
# | Metrics                    | Accuracy |
# | Features                   | Description |
# | Number of Terms            |        100, 150, 200, 250, 300
# |
# | Balancing                  |        Smote   |
# | Resampling                 |        Repeated CV 5 x 10       |
# | Threshold                  |        365       |
#
#
#
#
#
#
#
#
# Every bug which its report have indicated that the number of days to resolve is less than or equal to **threshold fixed** was considered a **non-long lived bug** and that which the number of days to resolve is greater than this threshold was considered as a **long-live bug**.

# %% [markdown]
# ## 4.2 Review Data

# %%
eclipse_metrics_in_train = pd.read_csv("../output/data/20200916_r4_2b_predict_long_lived_bug_train_final.csv", sep=",")
eclipse_metrics_in_train['sensitivity']  =  eclipse_metrics_in_train['tp']/(eclipse_metrics_in_train['tp']+eclipse_metrics_in_train['fn'])  
eclipse_metrics_in_train['specificity']  =  eclipse_metrics_in_train['tn']/(eclipse_metrics_in_train['tn']+eclipse_metrics_in_train['fp'])
eclipse_metrics_in_train['balanced_acc'] =  (eclipse_metrics_in_train['sensitivity']+eclipse_metrics_in_train['specificity'])/2
eclipse_metrics_in_train.tail(20)
# Out:
#        tn  fp  fn    tp     Resample                acc  sensitivity  \
# 230  1748  14  49  1636  Fold1.Rep07  0,981723237597911        0.971
# 231  1756   6  43  1642  Fold2.Rep07  0,985784740353931        0.974
# 232  1751  12  54  1631  Fold3.Rep07  0,980858468677494        0.968
# 233  1755   7  44  1640  Fold4.Rep07  0,985200232153221        0.974
# 234  1753   9  51  1634  Fold5.Rep07  0,982593559617058        0.970
# 235  1752  10  48  1637  Fold1.Rep08   0,98317377429649        0.972
# 236  1751  11  52  1632  Fold2.Rep08  0,981717933836332        0.969
# 237  1750  12  49  1636  Fold3.Rep08  0,982303452277343        0.971
# 238  1750  13  43  1642  Fold4.Rep08  0,983758700696056        0.974
# 239  1754   8  54  1631  Fold5.Rep08  0,982013344937627        0.968
# 240  1755   8  52  1633  Fold1.Rep09  0,982598607888631        0.969
# 241  1754   8  57  1627  Fold2.Rep09  0,981137550783517        0.966
# 242  1752  10  40  1645  Fold3.Rep09  0,985494633014215        0.976
# 243  1754   8  45  1640  Fold4.Rep09  0,984624310995068        0.973
# 244  1754   8  43  1642  Fold5.Rep09    0,9852045256745        0.974
# 245  1759   4  58  1627  Fold1.Rep10  0,982018561484919        0.966
# 246  1751  11  51  1633  Fold2.Rep10  0,982008125362739        0.970
# 247  1750  12  41  1644  Fold3.Rep10  0,984624310995068        0.976
# 248  1750  12  57  1628  Fold4.Rep10  0,979982593559617        0.966
# 249  1753   9  42  1643  Fold5.Rep10    0,9852045256745        0.975
#
#      specificity  balanced_acc  project classifier balancing      resampling  \
# 230        0.992         0.981  eclipse        svm     smote  repeatedcv5x10
# 231        0.997         0.986  eclipse        svm     smote  repeatedcv5x10
# 232        0.993         0.981  eclipse        svm     smote  repeatedcv5x10
# 233        0.996         0.985  eclipse        svm     smote  repeatedcv5x10
# 234        0.995         0.982  eclipse        svm     smote  repeatedcv5x10
# 235        0.994         0.983  eclipse        svm     smote  repeatedcv5x10
# 236        0.994         0.981  eclipse        svm     smote  repeatedcv5x10
# 237        0.993         0.982  eclipse        svm     smote  repeatedcv5x10
# 238        0.993         0.984  eclipse        svm     smote  repeatedcv5x10
# 239        0.995         0.982  eclipse        svm     smote  repeatedcv5x10
# 240        0.995         0.982  eclipse        svm     smote  repeatedcv5x10
# 241        0.995         0.981  eclipse        svm     smote  repeatedcv5x10
# 242        0.994         0.985  eclipse        svm     smote  repeatedcv5x10
# 243        0.995         0.984  eclipse        svm     smote  repeatedcv5x10
# 244        0.995         0.985  eclipse        svm     smote  repeatedcv5x10
# 245        0.998         0.982  eclipse        svm     smote  repeatedcv5x10
# 246        0.994         0.982  eclipse        svm     smote  repeatedcv5x10
# 247        0.993         0.984  eclipse        svm     smote  repeatedcv5x10
# 248        0.993         0.980  eclipse        svm     smote  repeatedcv5x10
# 249        0.995         0.985  eclipse        svm     smote  repeatedcv5x10
#
#        metric  max_term           feature hyper1   value1 hyper2  value2  \
# 230  Accuracy       300  long_description  sigma  0,03125      C      32
# 231  Accuracy       300  long_description  sigma  0,03125      C      32
# 232  Accuracy       300  long_description  sigma  0,03125      C      32
# 233  Accuracy       300  long_description  sigma  0,03125      C      32
# 234  Accuracy       300  long_description  sigma  0,03125      C      32
# 235  Accuracy       300  long_description  sigma  0,03125      C      32
# 236  Accuracy       300  long_description  sigma  0,03125      C      32
# 237  Accuracy       300  long_description  sigma  0,03125      C      32
# 238  Accuracy       300  long_description  sigma  0,03125      C      32
# 239  Accuracy       300  long_description  sigma  0,03125      C      32
# 240  Accuracy       300  long_description  sigma  0,03125      C      32
# 241  Accuracy       300  long_description  sigma  0,03125      C      32
# 242  Accuracy       300  long_description  sigma  0,03125      C      32
# 243  Accuracy       300  long_description  sigma  0,03125      C      32
# 244  Accuracy       300  long_description  sigma  0,03125      C      32
# 245  Accuracy       300  long_description  sigma  0,03125      C      32
# 246  Accuracy       300  long_description  sigma  0,03125      C      32
# 247  Accuracy       300  long_description  sigma  0,03125      C      32
# 248  Accuracy       300  long_description  sigma  0,03125      C      32
# 249  Accuracy       300  long_description  sigma  0,03125      C      32
#
#      seed  row
# 230   144    5
# 231   144    5
# 232   144    5
# 233   144    5
# 234   144    5
# 235   144    5
# 236   144    5
# 237   144    5
# 238   144    5
# 239   144    5
# 240   144    5
# 241   144    5
# 242   144    5
# 243   144    5
# 244   144    5
# 245   144    5
# 246   144    5
# 247   144    5
# 248   144    5
# 249   144    5

# %%
eclipse_metrics_in_train[['classifier', 'max_term']].value_counts()
# Out:
# classifier  max_term
# svm         300         50
#             250         50
#             200         50
#             150         50
#             100         50
# dtype: int64

# %%
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train.groupby(['classifier', 'feature', 'balancing', 'metric', 'max_term']).agg({'sensitivity': 'mean', 'specificity':'mean', 'balanced_acc': 'mean'})
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train_summarized.reset_index()
eclipse_metrics_in_train_summarized.sort_values('balanced_acc', ascending=False)
# Out:
#   classifier           feature balancing    metric  max_term  sensitivity  \
# 1        svm  long_description     smote  Accuracy       150        0.994
# 2        svm  long_description     smote  Accuracy       200        0.987
# 3        svm  long_description     smote  Accuracy       250        0.981
# 4        svm  long_description     smote  Accuracy       300        0.971
# 0        svm  long_description     smote  Accuracy       100        0.997
#
#    specificity  balanced_acc
# 1        0.985         0.989
# 2        0.991         0.989
# 3        0.994         0.987
# 4        0.995         0.983
# 0        0.966         0.981

# %% [markdown]
# ## 4.3 Evaluation Metrics

# %%
from  matplotlib.ticker import PercentFormatter
import matplotlib.ticker as ticker

def plot_line(x_ticks, x_label, experiment, data, id_var):
    sns.set_context("paper")
    sns.set(style="ticks", color_codes=True)
    e2_metrics_data_melted = data[[id_var, 'sensitivity', 'specificity', 'balanced_acc']].melt(id_vars=[id_var]) 

    plt.plot(id_var, 'value', data=e2_metrics_data_melted[e2_metrics_data_melted.variable=='sensitivity'], label="Sensitivity", marker='*', markerfacecolor='tab:green', markersize=8, color='tab:green', linewidth=2)
    plt.plot(id_var, 'value', data=e2_metrics_data_melted[e2_metrics_data_melted.variable=='specificity'], label="Specificity", marker='o', markerfacecolor='tab:blue',  markersize=8, color='tab:blue', linewidth=2)
    plt.plot(id_var, 'value', data=e2_metrics_data_melted[e2_metrics_data_melted.variable=='balanced_acc'], label="Balanced Accuracy", marker='x',markerfacecolor='tab:red',   markersize=8, color='tab:red', linewidth=2)
    sns.despine(offset=5)

    ax = plt.axes()
    
    plt.xticks(x_ticks)
    plt.xlabel(x_label, fontsize=SMALL_SIZE)
    
    plt.yticks(fontsize=SMALL_SIZE)
    plt.ylabel('Score', fontsize=SMALL_SIZE)
    plt.ylim(0, 1.1)
    plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
    plt.grid(linestyle='--', linewidth=0.5, alpha=0.5)

    plt.title("Eclipse: Evaluation Metrics", fontsize=SMALL_SIZE)
    plt.legend()
    plt.savefig(f"../output/figures/rq4e{experiment}-eclipse-evaluation-metrics.pdf", format="pdf", dpi=600, bbox_inches='tight')

# %%
plot_line([100, 150, 200, 250, 300], "Number of Terms", "2", eclipse_metrics_in_train_summarized, "max_term")
# Out:
# <ipython-input-14-f41e5573a59f>:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-14-f41e5573a59f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # 5. Third Experiment (RQ4.3)

# %% [markdown]
# ## 5.1 Parameters

# %% [markdown]
# | Parameter                  |         Value        |
# |----------------------------|:--------------------:|
# | Project                    |        Eclipse       |
# | Algorithms                 |        SVM |
# | Metrics                    | Accuracy |
# | Features                   | Description |
# | Number of Terms            |        150      |
# | Balancing                  |        Smote   |
# | Resampling                 |        Repeated CV 5 x 10       |
# | Threshold                  |        1, 8, 63, 365       |
#
#
#
#
#
#
#
#
# Every bug which its report have indicated that the number of days to resolve is less than or equal to **threshold fixed** was considered a **non-long lived bug** and that which the number of days to resolve is greater than this threshold was considered as a **long-live bug**.

# %% [markdown]
# ## 5.2 Review Data

# %%
eclipse_metrics_in_train = pd.read_csv("../output/data/20200916_r4_3b_predict_long_lived_bug_train_final.csv", sep=",")
eclipse_metrics_in_train.head()
# Out:
#     tn   fp   fn   tp     Resample   acc  sensitivity  specificity  \
# 0  592  363  537  403  Fold1.Rep01 0.525        0.429        0.620
# 1  621  334  521  418  Fold2.Rep01 0.549        0.445        0.650
# 2  613  342  528  411  Fold3.Rep01 0.541        0.438        0.642
# 3  619  336  544  395  Fold4.Rep01 0.535        0.421        0.648
# 4  615  339  540  399  Fold5.Rep01 0.536        0.425        0.645
#
#    balanced_acc  project classifier balancing      resampling    metric  \
# 0         0.524  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 1         0.548  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 2         0.540  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 3         0.534  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 4         0.535  eclipse        svm     smote  repeatedcv5x10  Accuracy
#
#    max_term           feature  threshold hyper1  value1 hyper2  value2  seed  \
# 0       150  long_description          8  sigma   0.031      C      32   144
# 1       150  long_description          8  sigma   0.031      C      32   144
# 2       150  long_description          8  sigma   0.031      C      32   144
# 3       150  long_description          8  sigma   0.031      C      32   144
# 4       150  long_description          8  sigma   0.031      C      32   144
#
#    row
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
eclipse_metrics_in_train[['classifier', 'threshold']].value_counts()
# Out:
# classifier  threshold
# svm         365          50
#             102          50
#             59           50
#             8            50
# dtype: int64

# %%
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train.groupby(['classifier', 'feature', 'balancing', 'metric', 'max_term', 'threshold']).agg({'sensitivity': 'mean', 'specificity':'mean', 'balanced_acc': 'mean'})
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train_summarized.reset_index()
eclipse_metrics_in_train_summarized.sort_values('balanced_acc', ascending=False)
# Out:
#   classifier           feature balancing    metric  max_term  threshold  \
# 3        svm  long_description     smote  Accuracy       150        365
# 2        svm  long_description     smote  Accuracy       150        102
# 1        svm  long_description     smote  Accuracy       150         59
# 0        svm  long_description     smote  Accuracy       150          8
#
#    sensitivity  specificity  balanced_acc
# 3        0.994        0.985         0.989
# 2        0.936        0.939         0.937
# 1        0.740        0.913         0.827
# 0        0.432        0.644         0.538

# %% [markdown]
# ## 5.3 Evaluation Metrics

# %%
plot_line([8, 63, 108, 365], "Bug Fixing Time Threshold", "3", eclipse_metrics_in_train_summarized, "threshold")
# Out:
# <ipython-input-14-f41e5573a59f>:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-14-f41e5573a59f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # 6. Fourth Experiment

# %% [markdown]
# ## 6.1 Parameters

# %% [markdown]
# | Parameter                  |         Value        |
# |----------------------------|:--------------------:|
# | Project                    |        Eclipse, Freedesktop, Gcc, Gnome, Mozilla, WineHQ       |
# | Algorithms                 |        NN |
# | Metrics                    | Accuracy |
# | Features                   | Long Description |
# | Number of Terms            |        150       |
# | Balancing                  |        Smote   |
# | Resampling                 |        Repeated CV 5 x 2       |
# | Threshold                  |        365       |
#
#
#
#
#
#
#
#
# Every bug which its report have indicated that the number of days to resolve is less than or equal to **threshold fixed** was considered a **non-long lived bug** and that which the number of days to resolve is greater than this threshold was considered as a **long-live bug**.

# %% [markdown]
# ## 6.2 Review Data

# %%
eclipse_metrics_in_train = pd.read_csv("../output/data/20200919_r4_4b_predict_long_lived_bug_train_final.csv", sep=",")
eclipse_metrics_in_train.head()
# Out:
#      tn  fp  fn    tp     Resample   acc  sensitivity  specificity  \
# 0  1294  22   4  1256  Fold1.Rep01 0.990        0.997        0.983
# 1  1294  21   8  1252  Fold2.Rep01 0.989        0.994        0.984
# 2  1300  16   7  1253  Fold3.Rep01 0.991        0.994        0.988
# 3  1299  17  10  1250  Fold4.Rep01 0.990        0.992        0.987
# 4  1287  28  15  1245  Fold5.Rep01 0.983        0.988        0.979
#
#    balanced_acc  project classifier balancing      resampling    metric  \
# 0         0.990  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 1         0.989  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 2         0.991  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 3         0.990  eclipse        svm     smote  repeatedcv5x10  Accuracy
# 4         0.983  eclipse        svm     smote  repeatedcv5x10  Accuracy
#
#    max_term           feature  threshold hyper1  value1 hyper2  value2  seed  \
# 0       150  long_description        365  sigma   0.031      C      32   144
# 1       150  long_description        365  sigma   0.031      C      32   144
# 2       150  long_description        365  sigma   0.031      C      32   144
# 3       150  long_description        365  sigma   0.031      C      32   144
# 4       150  long_description        365  sigma   0.031      C      32   144
#
#    row
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
eclipse_metrics_in_train[['classifier', 'project']].value_counts()
# Out:
# classifier  project
# svm         winehq         50
#             mozilla        50
#             gnome          50
#             gcc            50
#             freedesktop    50
#             eclipse        50
# dtype: int64

# %%
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train.groupby(['project', 'classifier', 'feature', 'balancing', 'metric', 'max_term', 'threshold']).agg({'sensitivity': 'mean', 'specificity':'mean', 'balanced_acc': 'mean'})
eclipse_metrics_in_train_summarized = eclipse_metrics_in_train_summarized.reset_index()

# %%
eclipse_metrics_in_train_summarized.sort_values('balanced_acc', ascending=False)
# Out:
#        project classifier           feature balancing    metric  max_term  \
# 0      eclipse        svm  long_description     smote  Accuracy       150
# 1  freedesktop        svm  long_description     smote  Accuracy       150
# 3        gnome        svm  long_description     smote  Accuracy       150
# 2          gcc        svm  long_description     smote  Accuracy       150
# 4      mozilla        svm  long_description     smote  Accuracy       150
# 5       winehq        svm  long_description     smote  Accuracy       150
#
#    threshold  sensitivity  specificity  balanced_acc
# 0        365        0.993        0.984         0.989
# 1        365        0.968        0.962         0.965
# 3        365        0.959        0.966         0.962
# 2        365        0.960        0.964         0.962
# 4        365        0.935        0.952         0.944
# 5        365        0.203        0.863         0.533

# %% [markdown]
# ## 6.3 Evaluation Train Metrics

# %%
sns.despine(offset=5)
sns.set(style="whitegrid")
e4_metrics_data_melted = eclipse_metrics_in_train_summarized[['project', 'sensitivity', 'specificity', 'balanced_acc']].melt(id_vars=['project']) 
g = sns.catplot(data=e4_metrics_data_melted
                , kind="bar"
                , x="project"
                , y="value"
                , hue="variable"
                , height=6
                , aspect=2
                , palette=["tab:green", "tab:blue", "tab:red"])
(g.set_axis_labels("", "")
  .set_titles(" SVM Performance")
  .set(ylim=(0,1))
  .despine(left=True))

# Format y scale in percentage format. 
for ax in g.axes.flat:
    ax.yaxis.set_major_formatter(PercentFormatter(1))

# Change and ajust legend. 
box = g.ax.get_position()
g.ax.set_position([box.x0, box.y0, box.width * 0.95, box.height]) # resize position
g._legend.set_title("Evaluating Metrics")
for t, l in zip(g._legend.texts, ['Sensitivity', 'Specificity', 'Balanced Accuracy']): t.set_text(l)

plt.show(g)
plt.savefig("../output/figures/r4e4_svm_performace_algorithms_on_all_dataset_in_train.pdf", format="pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ## 6.4 Evaluation Test Metrics

# %%
test_metrics_nn = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_train_all_w_nn_final.csv",\
                                       sep=",", decimal=",")
test_metrics_eclipse = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_eclipse_final.csv",\
                                       sep=",", decimal=",")
test_metrics_freedesktop = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_freedesktop_final.csv",\
                                       sep=",")
test_metrics_gcc = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_gcc_final.csv",\
                                       sep=",")
test_metrics_gnome = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_gnome_final.csv",\
                                       sep=",")
test_metrics_mozilla = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_mozilla_final.csv",\
                                       sep=",")
test_metrics_winehq = pd.read_csv("../output/data/20201103_r4_4b_predict_long_lived_bug_test_winehq_final.csv",\
                                       sep=",")

test_metrics_frames = [test_metrics_nn, test_metrics_eclipse, test_metrics_freedesktop, test_metrics_gcc,\
                      test_metrics_gnome, test_metrics_mozilla, test_metrics_winehq]
test_metrics_all  = pd.concat(test_metrics_frames)
#test_metrics_all  = test_metrics_all[['project', 'classifier', 'sensitivity', 'specificity', 'balanced_acc']].melt(id_vars=['project', 'classifier']) 
#test_metrics_all  = test_metrics_all[['project', 'classifier', 'balanced_acc']].melt(id_vars=['project', 'classifier'])

# %%
test_metrics_all
# Out:
#        project           feature  max_term classifier balancing  \
# 0      eclipse  long_description       100         nn     smote
# 1  freedesktop  long_description       100         nn     smote
# 2          gcc  long_description       100         nn     smote
# 3        gnome  long_description       100         nn     smote
# 4      mozilla  long_description       100         nn     smote
# 5       winehq  long_description       100         nn     smote
# 0      eclipse  long_description       100        knn     smote
# 1      eclipse  long_description       100         rf     smote
# 2      eclipse  long_description       100        svm     smote
# 3      eclipse  long_description       100         nb     smote
# 0  freedesktop  long_description       100        knn     smote
# 1  freedesktop  long_description       100         rf     smote
# 2  freedesktop  long_description       100        svm     smote
# 3  freedesktop  long_description       100         nb     smote
# 0          gcc  long_description       100        knn     smote
# 1          gcc  long_description       100         rf     smote
# 2          gcc  long_description       100        svm     smote
# 3          gcc  long_description       100         nb     smote
# 0        gnome  long_description       100        knn     smote
# 1        gnome  long_description       100         rf     smote
# 2        gnome  long_description       100        svm     smote
# 3        gnome  long_description       100         nb     smote
# 0      mozilla  long_description       100        knn     smote
# 1      mozilla  long_description       100         rf     smote
# 2      mozilla  long_description       100        svm     smote
# 3      mozilla  long_description       100         nb     smote
# 0       winehq  long_description       100        knn     smote
# 1       winehq  long_description       100         rf     smote
# 2       winehq  long_description       100        svm     smote
# 3       winehq  long_description       100         nb     smote
#
#       resampling    metric  threshold  train_size  train_size_class_0  \
# 0     repeatedcv  Accuracy        365       12847                6665
# 1     repeatedcv  Accuracy        365        9606                4908
# 2     repeatedcv  Accuracy        365        9616                5268
# 3     repeatedcv  Accuracy        365        9287                5017
# 4     repeatedcv  Accuracy        365       11170                5918
# 5     repeatedcv  Accuracy        365        4527                2688
# 0  repeatedcv5x2  Accuracy        365       12811                6547
# 1  repeatedcv5x2  Accuracy        365       12811                6547
# 2  repeatedcv5x2  Accuracy        365       12811                6547
# 3  repeatedcv5x2  Accuracy        365       12811                6547
# 0  repeatedcv5x2  Accuracy        365        9591                4893
# 1  repeatedcv5x2  Accuracy        365        9591                4893
# 2  repeatedcv5x2  Accuracy        365        9591                4893
# 3  repeatedcv5x2  Accuracy        365        9591                4893
# 0  repeatedcv5x2  Accuracy        365       12318                6233
# 1  repeatedcv5x2  Accuracy        365       12318                6233
# 2  repeatedcv5x2  Accuracy        365       12318                6233
# 3  repeatedcv5x2  Accuracy        365       12318                6233
# 0  repeatedcv5x2  Accuracy        365        9130                4915
# 1  repeatedcv5x2  Accuracy        365        9130                4915
# 2  repeatedcv5x2  Accuracy        365        9130                4915
# 3  repeatedcv5x2  Accuracy        365        9130                4915
# 0  repeatedcv5x2  Accuracy        365       11168                5916
# 1  repeatedcv5x2  Accuracy        365       11168                5916
# 2  repeatedcv5x2  Accuracy        365       11168                5916
# 3  repeatedcv5x2  Accuracy        365       11168                5916
# 0  repeatedcv5x2  Accuracy        365        4529                2688
# 1  repeatedcv5x2  Accuracy        365        4529                2688
# 2  repeatedcv5x2  Accuracy        365        4529                2688
# 3  repeatedcv5x2  Accuracy        365        4529                2688
#
#    train_size_class_1  test_size  test_size_class_0  test_size_class_1   tp  \
# 0                6182       2408               2221                187   71
# 1                4698       1895               1635                260  128
# 2                4348       2480               1756                724  380
# 3                4270       1956               1672                284  133
# 4                5252       2409               1972                437  248
# 5                1839       1507                895                612  181
# 0                6264       2356               2182                174   87
# 1                6264       2356               2182                174   10
# 2                6264       2356               2182                174    6
# 3                6264       2356               2182                174   73
# 0                4698       1891               1631                260  146
# 1                4698       1891               1631                260   30
# 2                4698       1891               1631                260   17
# 3                4698       1891               1631                260  126
# 0                6085       2482               2077                405  242
# 1                6085       2482               2077                405   50
# 2                6085       2482               2077                405   31
# 3                6085       2482               2077                405  180
# 0                4215       1918               1638                280  175
# 1                4215       1918               1638                280   61
# 2                4215       1918               1638                280   59
# 3                4215       1918               1638                280  143
# 0                5252       2408               1971                437  278
# 1                5252       2408               1971                437  111
# 2                5252       2408               1971                437   76
# 3                5252       2408               1971                437  221
# 0                1841       1508                895                613  244
# 1                1841       1508                895                613  239
# 2                1841       1508                895                613  210
# 3                1841       1508                895                613  131
#
#      fp    tn   fn  sensitivity  specificity  balanced_acc  \
# 0   656  1565  116     0.379679     0.704638      0.542158
# 1   627  1008  132     0.492308     0.616514      0.554411
# 2   192  1564  344     0.524862     0.890661      0.707761
# 3   466  1206  151     0.468310     0.721292      0.594801
# 4   652  1320  189     0.567506     0.669371      0.618438
# 5   149   746  431     0.295752     0.833520      0.564636
# 0   876  1306   87     0.500000     0.598533      0.549267
# 1    79  2103  164     0.057471     0.963795      0.510633
# 2    47  2135  168     0.034483     0.978460      0.506471
# 3   804  1378  101     0.419540     0.631531      0.525535
# 0   793   838  114     0.561538     0.513795      0.537667
# 1   148  1483  230     0.115385     0.909258      0.512321
# 2    86  1545  243     0.065385     0.947272      0.506328
# 3   688   943  134     0.484615     0.578173      0.531394
# 0  1096   981  163     0.597531     0.472316      0.534923
# 1   187  1890  355     0.123457     0.909966      0.516712
# 2   129  1948  374     0.076543     0.937891      0.507217
# 3   900  1177  225     0.444444     0.566683      0.505564
# 0   698   940  105     0.625000     0.573871      0.599435
# 1    75  1563  219     0.217857     0.954212      0.586035
# 2    89  1549  221     0.210714     0.945665      0.578190
# 3   681   957  137     0.510714     0.584249      0.547482
# 0  1033   938  159     0.636156     0.475901      0.556028
# 1   217  1754  326     0.254005     0.889904      0.571954
# 2   170  1801  361     0.173913     0.913749      0.543831
# 3   838  1133  216     0.505721     0.574835      0.540278
# 0   298   597  369     0.398042     0.667039      0.532541
# 1   216   679  374     0.389886     0.758659      0.574273
# 2   216   679  403     0.342577     0.758659      0.550618
# 3   158   737  482     0.213703     0.823464      0.518583
#
#    balanced_acc_manual  precision    recall  fmeasure  seed   row   seed
# 0             0.542158   0.097662  0.379679  0.155361  144.0    1    NaN
# 1             0.554411   0.169536  0.492308  0.252217  144.0    1    NaN
# 2             0.707761   0.664336  0.524862  0.586420  144.0    1    NaN
# 3             0.594801   0.222037  0.468310  0.301246  144.0    1    NaN
# 4             0.618438   0.275556  0.567506  0.370980  144.0    1    NaN
# 5             0.564636   0.548485  0.295752  0.384289  144.0    1    NaN
# 0             0.549267   0.090343  0.500000  0.153034    NaN    1  144.0
# 1             0.510633   0.112360  0.057471  0.076046    NaN    3  144.0
# 2             0.506471   0.113208  0.034483  0.052863    NaN    4  144.0
# 3             0.525535   0.083238  0.419540  0.138915    NaN    1  144.0
# 0             0.537667   0.155485  0.561538  0.243536    NaN    1  144.0
# 1             0.512321   0.168539  0.115385  0.136986    NaN    2  144.0
# 2             0.506328   0.165049  0.065385  0.093664    NaN    3  144.0
# 3             0.531394   0.154791  0.484615  0.234637    NaN    1  144.0
# 0             0.534923   0.180867  0.597531  0.277682    NaN    1  144.0
# 1             0.516712   0.210970  0.123457  0.155763    NaN    2  144.0
# 2             0.507217   0.193750  0.076543  0.109735    NaN    3  144.0
# 3             0.505564   0.166667  0.444444  0.242424    NaN    1  144.0
# 0             0.599435   0.200458  0.625000  0.303556    NaN    1  144.0
# 1             0.586035   0.448529  0.217857  0.293269    NaN    2  144.0
# 2             0.578190   0.398649  0.210714  0.275701    NaN    3  144.0
# 3             0.547482   0.173544  0.510714  0.259058    NaN    1  144.0
# 0             0.556028   0.212052  0.636156  0.318078    NaN    1  144.0
# 1             0.571954   0.338415  0.254005  0.290196    NaN    2  144.0
# 2             0.543831   0.308943  0.173913  0.222548    NaN    3  144.0
# 3             0.540278   0.208687  0.505721  0.295455    NaN    1  144.0
# 0             0.532541   0.450185  0.398042  0.422511    NaN    1  144.0
# 1             0.574273   0.525275  0.389886  0.447566    NaN    2  144.0
# 2             0.550618   0.492958  0.342577  0.404235    NaN    3  144.0
# 3             0.518583   0.453287  0.213703  0.290466    NaN    1  144.0

# %%
from  matplotlib.ticker import PercentFormatter
import matplotlib.ticker as ticker

def plot_line_(experiment, data, project):
    sns.set_context("paper")
    sns.set(style="ticks", color_codes=True)
    
    data_m  = data[(data.project == project)] 
    data_m  = data_m[['classifier', 'balanced_acc']].melt(id_vars=['classifier']) 
    print(data_m)

    data_m.sort_values('classifier').plot('classifier', 'value', label="Balanced Accuracy", kind="bar", legend=None, 
                color=['tab:blue', 'tab:pink', 'tab:green', 'tab:purple', 'tab:orange'])
    sns.despine(offset=5)

    ax = plt.axes()
    
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        ax.annotate(f'{height:.1%}', (x + width/2, y + height*1.02), ha='center')

    plt.xlabel("", fontsize=SMALL_SIZE)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=12)
    plt.ylabel('balanced accuracy', fontsize=SMALL_SIZE)
    plt.ylim(0.2, 0.8)
    plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
    plt.grid(linestyle='--', linewidth=0.5, alpha=0.5)

    #plt.title("{}".format(project), fontsize=SMALL_SIZE)
    plt.savefig(f"../output/figures/rq4e{experiment}-{project}-evaluation-all-classifiers.pdf", format="pdf", dpi=600, bbox_inches='tight')

# %%
plot_line_("4", test_metrics_all, "eclipse")
plot_line_("4", test_metrics_all, "freedesktop")
plot_line_("4", test_metrics_all, "gnome")
plot_line_("4", test_metrics_all, "gcc") 
plot_line_("4", test_metrics_all, "mozilla") 
plot_line_("4", test_metrics_all, "winehq")
# Out:
#   classifier      variable     value
# 0         nn  balanced_acc  0.542158
# 1        knn  balanced_acc  0.549267
# 2         rf  balanced_acc  0.510633
# 3        svm  balanced_acc  0.506471
# 4         nb  balanced_acc  0.525535
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
#   classifier      variable     value
# 0         nn  balanced_acc  0.554411
# 1        knn  balanced_acc  0.537667
# 2         rf  balanced_acc  0.512321
# 3        svm  balanced_acc  0.506328
# 4         nb  balanced_acc  0.531394
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
#   classifier      variable     value
# 0         nn  balanced_acc  0.594801
# 1        knn  balanced_acc  0.599435
# 2         rf  balanced_acc  0.586035
# 3        svm  balanced_acc  0.578190
# 4         nb  balanced_acc  0.547482
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
#   classifier      variable     value
# 0         nn  balanced_acc  0.707761
# 1        knn  balanced_acc  0.534923
# 2         rf  balanced_acc  0.516712
# 3        svm  balanced_acc  0.507217
# 4         nb  balanced_acc  0.505564
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
#   classifier      variable     value
# 0         nn  balanced_acc  0.618438
# 1        knn  balanced_acc  0.556028
# 2         rf  balanced_acc  0.571954
# 3        svm  balanced_acc  0.543831
# 4         nb  balanced_acc  0.540278
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
#   classifier      variable     value
# 0         nn  balanced_acc  0.564636
# 1        knn  balanced_acc  0.532541
# 2         rf  balanced_acc  0.574273
# 3        svm  balanced_acc  0.550618
# 4         nb  balanced_acc  0.518583
# <ipython-input-22-9e86eb8fc1f4>:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# <ipython-input-22-9e86eb8fc1f4>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

# %%
import matplotlib.ticker as mtick

ax = plt.plot(kind="bar", color=["tab:blue", "tab:red"])
sns.despine(offset=5)

plt.ylim(0, 1)
plt.grid(linestyle='--', linewidth=0.5, alpha=0.5)

plt.title('Sparsity of Feature Vector Matrix in Testing')
plt.xlabel('')
plt.ylabel('Ratio')
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# ## 6.4 Evaluation Test Metrics

# %%
from pandas import DataFrame

metrics = {'dataset': ['Eclipse', 'Freedesktop', 'Gnome', 'Mozilla', 'Gcc', 'WineHQ'],
        '% of Long-Lived Bugs': [7.2, 13.6, 14.5, 18.0, 16.5, 40.7],
        'Balanced Accuracy (%)': [54.21, 55.44, 59.48, 61.84, 70.77, 56.46]}

df = DataFrame(metrics)

print (df)
# Out:
#        dataset  % of Long-Lived Bugs  Balanced Accuracy (%)
# 0      Eclipse                   7.2                  54.21
# 1  Freedesktop                  13.6                  55.44
# 2        Gnome                  14.5                  59.48
# 3      Mozilla                  18.0                  61.84
# 4          Gcc                  16.5                  70.77
# 5       WineHQ                  40.7                  56.46

# %%
plt.rc('figure', figsize=(20, 20))
plt.style.use('default')

x=df['% of Long-Lived Bugs']
y=df['Balanced Accuracy (%)']

plt.scatter(x, y, s=100, color=['tab:blue', 'tab:pink', 'tab:green', 'tab:purple', 'tab:orange', 'tab:red'])
plt.xlim(0,50)
plt.ylim(50, 75)
plt.text(6, 55.5, 'Eclipse')
plt.text(10, 56.5, 'Freedesktop')
plt.text(12, 60.5, 'Gnome')
plt.text(16, 63.0, 'Mozilla')
plt.text(16, 72, 'GCC')
plt.text(38.5, 57.5, 'WineHQ')
plt.grid(linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('% of Long-Lived Bugs')
plt.ylabel('Balance Accuracy (%)')

sns.despine(offset=5, trim=True)
plt.savefig(f"../output/figures/r4e4_performace_algorithms_vs_percentage_of_long_lived.pdf", format="pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ## 6.4 Tests Results
