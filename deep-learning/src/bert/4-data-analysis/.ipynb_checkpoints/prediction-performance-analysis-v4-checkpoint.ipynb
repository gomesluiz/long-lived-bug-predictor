# %% [markdown]
# # Performance analysis of BERT for feature extraction

# %% [markdown]
# ## Eclipse project

# %% [markdown]
# | Parameter     | Value         |
# | ------------- |:-------------:|
# | Model         | bert-base-uncase |
# | Tokens        | 128     |
# | Threshold     | median      |

# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border: 1px solid lightgray;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border: 1px solid lightgray;
#     }
# </style>

# %%
import warnings
warnings.filterwarnings("ignore",category=UserWarning)

import pandas as pd

import plot_helper  as ph
import stats_helper as sh
# %matplotlib inline

reference   = '20210303'
projects    = ['eclipse', 'freedesktop', 'gnome', 'gcc', 'mozilla', 'winehq']
classifiers = {'knn':0, 'nb':1, 'nn':2, 'rf':3, 'svm':4, 'vc':5}
print('setup completed')
# Out:
# setup completed

# %% [markdown]
# ## Performance analysis in training

# %% [markdown]
# ### BERT vs. TF-IDF

# %% [markdown]
# ### Statistical test

# %%
#project='eclipse'
#bert_train_scores = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_bert_train_scores.csv')
#bert_train_scores['feature_extraction']='bert'
#bert_train_scores.to_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_bert_train_scores.csv', index=False)

#tfidf_train_scores = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_tfidf_train_scores.csv')
#tfidf_train_scores['feature_extraction']='tf-idf'
#tfidf_train_scores.to_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_tfidf_train_scores.csv', index=False)

# %%
#for project in projects:
#    bert_train_scores_1 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_bert_train_scores.csv')
#    bert_train_scores_2 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210301_{project}_feature_extraction_bert_train_scores.csv')
#    
#    pd.concat([bert_train_scores_1, bert_train_scores_2]).to_csv(f'../../../data/metrics/feature-extraction/20210303_{project}_feature_extraction_bert_train_scores.csv', index=False)
#    
#   
#    tfidf_train_scores_1 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_tfidf_train_scores.csv')
#    tfidf_train_scores_2 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210301_{project}_feature_extraction_tfidf_train_scores.csv')
#    
#    pd.concat([tfidf_train_scores_1, tfidf_train_scores_2]).to_csv(f'../../../data/metrics/feature-extraction/20210303_{project}_feature_extraction_tfidf_train_scores.csv', index=False)

# %%
#for project in projects:
#    bert_test_scores_1 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_bert_test_scores.csv')
#    bert_test_scores_2 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210301_{project}_feature_extraction_bert_test_scores.csv')
#    
#    pd.concat([bert_test_scores_1, bert_test_scores_2]).to_csv(f'../../../data/metrics/feature-extraction/20210303_{project}_feature_extraction_bert_test_scores.csv', index=False)
#    
#    
#    tfidf_test_scores_1 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210221_{project}_feature_extraction_tfidf_test_scores.csv')
#    tfidf_test_scores_2 = pd.read_csv(f'../../../data/metrics/feature-extraction/20210301_{project}_feature_extraction_tfidf_test_scores.csv')
#    
#    pd.concat([tfidf_test_scores_1, tfidf_test_scores_2]).to_csv(f'../../../data/metrics/feature-extraction/20210303_{project}_feature_extraction_tfidf_test_scores.csv', index=False)

# %%
for project in projects:
    bert_train_scores = pd.read_csv(f'../../../data/metrics/feature-extraction/{reference}_{project}_feature_extraction_bert_train_scores.csv')
    tfidf_train_scores = pd.read_csv(f'../../../data/metrics/feature-extraction/{reference}_{project}_feature_extraction_tfidf_train_scores.csv')

    best_bert_train_scores = bert_train_scores.copy()
    best_bert_train_scores.loc[:,['classifier']] = best_bert_train_scores['feature_extraction'] + ':' + best_bert_train_scores['classifier']
    best_tfidf_train_scores = tfidf_train_scores.copy()
    best_tfidf_train_scores.loc[:,['classifier']] = best_tfidf_train_scores['feature_extraction'] + ':' + best_tfidf_train_scores['classifier']

    all_train_scores = pd.concat([best_bert_train_scores, best_tfidf_train_scores])
    all_train_scores_pivoted = pd.pivot_table (all_train_scores, index='fold', columns='classifier', values=['balanced_acc'])
    statistical_test_results = sh.make_test(all_train_scores_pivoted, ['bert:knn', 'bert:nb', 'bert:nn', 'bert:svm', 'bert:rf', 'bert:vc', 'tf-idf:knn', 'tf-idf:nb', 'tf-idf:nn', 'tf-idf:svm', 'tf-idf:rf', 'tf-idf:vc'])
    statistical_test_results_sliced = statistical_test_results[['classifier1', 'classifier2', 'direction']]
    statistical_test_results_pivoted = statistical_test_results_sliced.pivot(index='classifier1', columns='classifier2', values='direction')
    print(f'Long-lived bug prediction performance statistical test for {project.capitalize()}: BERT versus TF-IDF features')
    display(statistical_test_results_pivoted)
# Out:
# Long-lived bug prediction performance statistical test for Eclipse: BERT versus TF-IDF features
# classifier2      bert:knn       bert:nb       bert:nn       bert:rf  \
# classifier1
# bert:knn              $-$    $\uparrow$  $\leftarrow$    $\uparrow$
# bert:nb      $\leftarrow$           $-$  $\leftarrow$           $-$
# bert:nn        $\uparrow$    $\uparrow$           $-$    $\uparrow$
# bert:rf      $\leftarrow$           $-$  $\leftarrow$           $-$
# bert:svm     $\leftarrow$           $-$  $\leftarrow$           $-$
# bert:vc      $\leftarrow$  $\leftarrow$  $\leftarrow$  $\leftarrow$
# tf-idf:knn     $\uparrow$    $\uparrow$    $\uparrow$    $\uparrow$
# tf-idf:nb      $\uparrow$    $\uparrow$           $-$    $\uparrow$
# tf-idf:nn      $\uparrow$    $\uparrow$    $\uparrow$    $\uparrow$
# tf-idf:rf             $-$    $\uparrow$  $\leftarrow$    $\uparrow$
# tf-idf:svm            $-$    $\uparrow$  $\leftarrow$    $\uparrow$
# ...

# %% [markdown]
# ## Performance analysis in testing

# %% [markdown]
# ### BERT vs. TF-IDF

# %%
ph.set_style()
classifiers_list = list(classifiers.keys())
for project in projects:
    test_scores_bert  = pd.read_csv(f'../../../data/metrics/feature-extraction/{reference}_{project}_feature_extraction_bert_test_scores.csv')
    test_scores_tfidf = pd.read_csv(f'../../../data/metrics/feature-extraction/{reference}_{project}_feature_extraction_tfidf_test_scores.csv')
    test_scores = pd.concat([test_scores_bert, test_scores_tfidf])
    
    best_balanced_acc_row = test_scores['balanced_acc'].argmax()
    best_classifier = test_scores.iloc[best_balanced_acc_row, 1]
    
    fig, axes =ph.plot_stacked_bar(test_scores, classifiers_list)
    ph.make_labels(fig, axes, project, classifiers_list)
    ph.set_size(fig)
    ph.color_bars(axes, ph.get_colors(), classifiers[best_classifier])
